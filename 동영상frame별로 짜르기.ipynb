# %%
import cv2
import numpy as np
import os

# set video file path of input video with name and extension
vid = cv2.VideoCapture('data.avi')


if not os.path.exists('images'):
    os.makedirs('images')

#for frame identity
index = 0
while(True):
    # Extract images
    ret, frame = vid.read()
    # end of frames
    if not ret: 
        break
    # Saves images
    name = './images/frame' + str(index) +'test2'+ '.jpg'
    print ('Creating...' + name)
    cv2.imwrite(name, frame)

    # next frame
    index += 1
# Out:
# Creating..../images/frame0test2.jpg
# Creating..../images/frame1test2.jpg
# Creating..../images/frame2test2.jpg
# Creating..../images/frame3test2.jpg
# Creating..../images/frame4test2.jpg
# Creating..../images/frame5test2.jpg
# Creating..../images/frame6test2.jpg
# Creating..../images/frame7test2.jpg
# Creating..../images/frame8test2.jpg
# Creating..../images/frame9test2.jpg
# Creating..../images/frame10test2.jpg
# Creating..../images/frame11test2.jpg
# Creating..../images/frame12test2.jpg
# Creating..../images/frame13test2.jpg
# Creating..../images/frame14test2.jpg
# Creating..../images/frame15test2.jpg
# Creating..../images/frame16test2.jpg
# Creating..../images/frame17test2.jpg
# Creating..../images/frame18test2.jpg
# Creating..../images/frame19test2.jpg
# Creating..../images/frame20test2.jpg
# Creating..../images/frame21test2.jpg
# Creating..../images/frame22test2.jpg
# Creating..../images/frame23test2.jpg
# Creating..../images/frame24test2.jpg
# ...
