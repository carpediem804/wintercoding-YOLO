# %%
# Script to convert yolo annotations to voc format

# Sample format
# <annotation>
#     <folder>_image_fashion</folder>
#     <filename>brooke-cagle-39574.jpg</filename>
#     <size>
#         <width>1200</width>
#         <height>800</height>
#         <depth>3</depth>
#     </size>
#     <segmented>0</segmented>
#     <object>
#         <name>head</name>
#         <pose>Unspecified</pose>
#         <truncated>0</truncated>
#         <difficult>0</difficult>
#         <bndbox>
#             <xmin>549</xmin>
#             <ymin>251</ymin>
#             <xmax>625</xmax>
#             <ymax>335</ymax>
#         </bndbox>
#     </object>
# <annotation>
import os
import xml.etree.cElementTree as ET
from PIL import Image

ANNOTATIONS_DIR_PREFIX = "bbox_txt"

DESTINATION_DIR = "converted_labels"

CLASS_MAPPING = {
    '0': 'pental sharp',
    '1': 'jetstream',
    '2': 'u-knock'
    # Add your remaining classes here.
}


def create_root(file_prefix, width, height):
    root = ET.Element("annotations")
    ET.SubElement(root, "filename").text = "{}.jpg".format(file_prefix)
    ET.SubElement(root, "folder").text = "images"
    size = ET.SubElement(root, "size")
    ET.SubElement(size, "width").text = str(width)
    ET.SubElement(size, "height").text = str(height)
    ET.SubElement(size, "depth").text = "3"
    return root


def create_object_annotation(root, voc_labels):
    for voc_label in voc_labels:
        obj = ET.SubElement(root, "object")
        ET.SubElement(obj, "name").text = voc_label[0]
        ET.SubElement(obj, "pose").text = "Unspecified"
        ET.SubElement(obj, "truncated").text = str(0)
        ET.SubElement(obj, "difficult").text = str(0)
        bbox = ET.SubElement(obj, "bndbox")
        ET.SubElement(bbox, "xmin").text = str(voc_label[1])
        ET.SubElement(bbox, "ymin").text = str(voc_label[2])
        ET.SubElement(bbox, "xmax").text = str(voc_label[3])
        ET.SubElement(bbox, "ymax").text = str(voc_label[4])
    return root


def create_file(file_prefix, width, height, voc_labels):
    root = create_root(file_prefix, width, height)
    root = create_object_annotation(root, voc_labels)
    tree = ET.ElementTree(root)
    tree.write("{}/{}.xml".format(DESTINATION_DIR, file_prefix))


def read_file(file_path):
    file_prefix = file_path.split(".txt")[0]
    image_file_name = "{}.jpg".format(file_prefix)
    img = Image.open("{}/{}".format("images", image_file_name))
    w, h = img.size
    with open(file_path, 'r') as file:
        lines = file.readlines()
        voc_labels = []
        for line in lines:
            voc = []
            line = line.strip()
            data = line.split()
            voc.append(CLASS_MAPPING.get(data[0]))
            bbox_width = float(data[3]) * w
            bbox_height = float(data[4]) * h
            center_x = float(data[1]) * w
            center_y = float(data[2]) * h
            voc.append(center_x - (bbox_width / 2))
            voc.append(center_y - (bbox_height / 2))
            voc.append(center_x + (bbox_width / 2))
            voc.append(center_y + (bbox_height / 2))
            voc_labels.append(voc)
        create_file(file_prefix, w, h, voc_labels)
    print("Processing complete for file: {}".format(file_path))


def start(dir_name):
    if not os.path.exists(DESTINATION_DIR):
        os.makedirs(DESTINATION_DIR)
    for filename in os.listdir(ANNOTATIONS_DIR_PREFIX):
        if filename.endswith('txt'):
            read_file(filename)
        else:
            print("Skipping file: {}".format(filename))


if __name__ == "__main__":
    start('annotation_xml')
# Out:
# Processing complete for file: data (1).txt
# Processing complete for file: data (10).txt
# Processing complete for file: data (100).txt
# Processing complete for file: data (101).txt
# Processing complete for file: data (102).txt
# Processing complete for file: data (103).txt
# Processing complete for file: data (104).txt
# Processing complete for file: data (105).txt
# Processing complete for file: data (106).txt
# Processing complete for file: data (107).txt
# Processing complete for file: data (108).txt
# Processing complete for file: data (109).txt
# Processing complete for file: data (11).txt
# Processing complete for file: data (110).txt
# Processing complete for file: data (111).txt
# Processing complete for file: data (112).txt
# Processing complete for file: data (113).txt
# Processing complete for file: data (114).txt
# Processing complete for file: data (115).txt
# Processing complete for file: data (116).txt
# Processing complete for file: data (117).txt
# Processing complete for file: data (118).txt
# Processing complete for file: data (119).txt
# Processing complete for file: data (12).txt
# Processing complete for file: data (120).txt
# Processing complete for file: data (121).txt
# Processing complete for file: data (122).txt
# Processing complete for file: data (123).txt
# Processing complete for file: data (124).txt
# Processing complete for file: data (125).txt
# Processing complete for file: data (126).txt
# Processing complete for file: data (127).txt
# Processing complete for file: data (128).txt
# Processing complete for file: data (129).txt
# Processing complete for file: data (13).txt
# Processing complete for file: data (130).txt
# Processing complete for file: data (131).txt
# Processing complete for file: data (132).txt
# Processing complete for file: data (133).txt
# Processing complete for file: data (134).txt
# Processing complete for file: data (135).txt
# Processing complete for file: data (136).txt
# Processing complete for file: data (137).txt
# Processing complete for file: data (138).txt
# Processing complete for file: data (139).txt
# Processing complete for file: data (14).txt
# Processing complete for file: data (140).txt
# Processing complete for file: data (141).txt
# Processing complete for file: data (142).txt
# Processing complete for file: data (143).txt
# Processing complete for file: data (144).txt
# Processing complete for file: data (145).txt
# Processing complete for file: data (146).txt
# Processing complete for file: data (147).txt
# Processing complete for file: data (148).txt
# Processing complete for file: data (149).txt
# Processing complete for file: data (15).txt
# Processing complete for file: data (150).txt
# Processing complete for file: data (151).txt
# Processing complete for file: data (152).txt
# Processing complete for file: data (153).txt
# Processing complete for file: data (154).txt
# Processing complete for file: data (155).txt
# Processing complete for file: data (156).txt
# Processing complete for file: data (157).txt
# Processing complete for file: data (158).txt
# Processing complete for file: data (159).txt
# Processing complete for file: data (16).txt
# Processing complete for file: data (160).txt
# Processing complete for file: data (161).txt
# Processing complete for file: data (162).txt
# Processing complete for file: data (163).txt
# Processing complete for file: data (164).txt
# Processing complete for file: data (165).txt
# Processing complete for file: data (166).txt
# Processing complete for file: data (167).txt
# Processing complete for file: data (168).txt
# Processing complete for file: data (169).txt
# Processing complete for file: data (17).txt
# Processing complete for file: data (170).txt
# Processing complete for file: data (171).txt
# Processing complete for file: data (172).txt
# Processing complete for file: data (173).txt
# Processing complete for file: data (174).txt
# Processing complete for file: data (175).txt
# Processing complete for file: data (176).txt
# Processing complete for file: data (177).txt
# Processing complete for file: data (178).txt
# Processing complete for file: data (179).txt
# Processing complete for file: data (18).txt
# Processing complete for file: data (180).txt
# Processing complete for file: data (181).txt
# Processing complete for file: data (182).txt
# Processing complete for file: data (183).txt
# Processing complete for file: data (184).txt
# Processing complete for file: data (185).txt
# Processing complete for file: data (186).txt
# Processing complete for file: data (187).txt
# Processing complete for file: data (188).txt
# Processing complete for file: data (189).txt
# Processing complete for file: data (19).txt
# Processing complete for file: data (190).txt
# Processing complete for file: data (191).txt
# Processing complete for file: data (192).txt
# Processing complete for file: data (193).txt
# Processing complete for file: data (194).txt
# Processing complete for file: data (195).txt
# Processing complete for file: data (196).txt
# Processing complete for file: data (197).txt
# Processing complete for file: data (198).txt
# Processing complete for file: data (199).txt
# Processing complete for file: data (2).txt
# Processing complete for file: data (20).txt
# Processing complete for file: data (200).txt
# Processing complete for file: data (201).txt
# Processing complete for file: data (202).txt
# Processing complete for file: data (203).txt
# Processing complete for file: data (204).txt
# Processing complete for file: data (205).txt
# Processing complete for file: data (206).txt
# Processing complete for file: data (207).txt
# Processing complete for file: data (208).txt
# Processing complete for file: data (209).txt
# Processing complete for file: data (21).txt
# Processing complete for file: data (210).txt
# Processing complete for file: data (211).txt
# Processing complete for file: data (212).txt
# Processing complete for file: data (213).txt
# Processing complete for file: data (214).txt
# Processing complete for file: data (215).txt
# Processing complete for file: data (216).txt
# Processing complete for file: data (217).txt
# Processing complete for file: data (218).txt
# Processing complete for file: data (219).txt
# Processing complete for file: data (22).txt
# Processing complete for file: data (220).txt
# Processing complete for file: data (221).txt
# Processing complete for file: data (222).txt
# Processing complete for file: data (223).txt
# Processing complete for file: data (224).txt
# Processing complete for file: data (225).txt
# Processing complete for file: data (226).txt
# Processing complete for file: data (227).txt
# Processing complete for file: data (228).txt
# Processing complete for file: data (229).txt
# Processing complete for file: data (23).txt
# Processing complete for file: data (230).txt
# Processing complete for file: data (231).txt
# Processing complete for file: data (232).txt
# Processing complete for file: data (233).txt
# Processing complete for file: data (234).txt
# Processing complete for file: data (235).txt
# Processing complete for file: data (236).txt
# Processing complete for file: data (237).txt
# Processing complete for file: data (238).txt
# Processing complete for file: data (239).txt
# Processing complete for file: data (24).txt
# Processing complete for file: data (240).txt
# Processing complete for file: data (241).txt
# Processing complete for file: data (242).txt
# Processing complete for file: data (243).txt
# Processing complete for file: data (244).txt
# Processing complete for file: data (245).txt
# Processing complete for file: data (246).txt
# Processing complete for file: data (247).txt
# Processing complete for file: data (248).txt
# Processing complete for file: data (249).txt
# Processing complete for file: data (25).txt
# Processing complete for file: data (250).txt
# Processing complete for file: data (251).txt
# Processing complete for file: data (252).txt
# Processing complete for file: data (253).txt
# Processing complete for file: data (254).txt
# Processing complete for file: data (255).txt
# Processing complete for file: data (256).txt
# Processing complete for file: data (257).txt
# Processing complete for file: data (258).txt
# Processing complete for file: data (259).txt
# Processing complete for file: data (26).txt
# Processing complete for file: data (260).txt
# Processing complete for file: data (261).txt
# Processing complete for file: data (262).txt
# Processing complete for file: data (263).txt
# Processing complete for file: data (264).txt
# Processing complete for file: data (265).txt
# Processing complete for file: data (266).txt
# Processing complete for file: data (267).txt
# Processing complete for file: data (268).txt
# Processing complete for file: data (269).txt
# Processing complete for file: data (27).txt
# Processing complete for file: data (270).txt
# Processing complete for file: data (271).txt
# Processing complete for file: data (272).txt
# Processing complete for file: data (273).txt
# Processing complete for file: data (274).txt
# Processing complete for file: data (275).txt
# Processing complete for file: data (276).txt
# Processing complete for file: data (277).txt
# Processing complete for file: data (278).txt
# Processing complete for file: data (279).txt
# Processing complete for file: data (28).txt
# Processing complete for file: data (280).txt
# Processing complete for file: data (281).txt
# Processing complete for file: data (282).txt
# Processing complete for file: data (283).txt
# Processing complete for file: data (284).txt
# Processing complete for file: data (285).txt
# Processing complete for file: data (286).txt
# Processing complete for file: data (287).txt
# Processing complete for file: data (288).txt
# Processing complete for file: data (289).txt
# Processing complete for file: data (29).txt
# Processing complete for file: data (290).txt
# Processing complete for file: data (291).txt
# Processing complete for file: data (292).txt
# Processing complete for file: data (293).txt
# Processing complete for file: data (294).txt
# Processing complete for file: data (295).txt
# Processing complete for file: data (296).txt
# Processing complete for file: data (297).txt
# Processing complete for file: data (298).txt
# Processing complete for file: data (299).txt
# Processing complete for file: data (3).txt
# Processing complete for file: data (30).txt
# Processing complete for file: data (300).txt
# Processing complete for file: data (31).txt
# Processing complete for file: data (32).txt
# Processing complete for file: data (33).txt
# Processing complete for file: data (34).txt
# Processing complete for file: data (35).txt
# Processing complete for file: data (36).txt
# Processing complete for file: data (37).txt
# Processing complete for file: data (38).txt
# Processing complete for file: data (39).txt
# Processing complete for file: data (4).txt
# Processing complete for file: data (40).txt
# Processing complete for file: data (41).txt
# Processing complete for file: data (42).txt
# Processing complete for file: data (43).txt
# Processing complete for file: data (44).txt
# Processing complete for file: data (45).txt
# Processing complete for file: data (46).txt
# Processing complete for file: data (47).txt
# Processing complete for file: data (48).txt
# Processing complete for file: data (49).txt
# Processing complete for file: data (5).txt
# Processing complete for file: data (50).txt
# Processing complete for file: data (51).txt
# Processing complete for file: data (52).txt
# Processing complete for file: data (53).txt
# Processing complete for file: data (54).txt
# Processing complete for file: data (55).txt
# Processing complete for file: data (56).txt
# Processing complete for file: data (57).txt
# Processing complete for file: data (58).txt
# Processing complete for file: data (59).txt
# Processing complete for file: data (6).txt
# Processing complete for file: data (60).txt
# Processing complete for file: data (61).txt
# Processing complete for file: data (62).txt
# Processing complete for file: data (63).txt
# Processing complete for file: data (64).txt
# Processing complete for file: data (65).txt
# Processing complete for file: data (66).txt
# Processing complete for file: data (67).txt
# Processing complete for file: data (68).txt
# Processing complete for file: data (69).txt
# Processing complete for file: data (7).txt
# Processing complete for file: data (70).txt
# Processing complete for file: data (71).txt
# Processing complete for file: data (72).txt
# Processing complete for file: data (73).txt
# Processing complete for file: data (74).txt
# Processing complete for file: data (75).txt
# Processing complete for file: data (76).txt
# Processing complete for file: data (77).txt
# Processing complete for file: data (78).txt
# Processing complete for file: data (79).txt
# Processing complete for file: data (8).txt
# Processing complete for file: data (80).txt
# Processing complete for file: data (81).txt
# Processing complete for file: data (82).txt
# Processing complete for file: data (83).txt
# Processing complete for file: data (84).txt
# Processing complete for file: data (85).txt
# Processing complete for file: data (86).txt
# Processing complete for file: data (87).txt
# Processing complete for file: data (88).txt
# Processing complete for file: data (89).txt
# Processing complete for file: data (9).txt
# Processing complete for file: data (90).txt
# Processing complete for file: data (91).txt
# Processing complete for file: data (92).txt
# Processing complete for file: data (93).txt
# Processing complete for file: data (94).txt
# Processing complete for file: data (95).txt
# Processing complete for file: data (96).txt
# Processing complete for file: data (97).txt
# Processing complete for file: data (98).txt
# Processing complete for file: data (99).txt
